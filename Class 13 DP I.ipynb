# %% [markdown]
# ### Q1 Fibonacci: F(n) = F(n-1) + F(n-2)

# %% [markdown]
# ### Q2. Longest Ascending Subarray
# Given an unsorted array, find the length of the longest subarray in which the numbers are in ascending order.
#
# For example: input [7,2,3,1,5,8,9,6], the subarray [1,5,8,9] is the LAS, output is 4

# %% [markdown]
# ### Q3. Maximal Product when Cutting Rope
# Given a rope with integer-length n, how to cut the rope into m interger-length parts with length p[0], p[1], ... p[m-1], in order to get the maximal product of p[0]*p[1]*...*p[m-1]? m is determined by you and must be greater than 0 (at least one cut must be made)

# %% [markdown]
# ### Q4. Jump Game
# Given an array of non-negative integers, you are initially positioned at the first index of the array. Each element in the array represents your maximum jump length at that position. Determine if you are able to reach the last index
#
# For example:
#
# A = [2,3,1,1,4] return true
#
# B = [3,2,1,0,4] return false
